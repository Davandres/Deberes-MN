# %% [markdown]
# # Deber 5

# %% [markdown]
# ## Ejercicio 1: Sea 𝑓(𝑥) = −𝑥3 − cos 𝑥 y 𝑝0 = −1. Use el método de Newton y de la Secante para encontrar 𝑝2. ¿Se podría usar 𝑝0 = 0?

# %% [markdown]
# ### Para el metodo de Newton:

# %%
import numpy as np
import matplotlib.pyplot as plt

def newton_raphson(fx, dfx, xi, tolera, iteramax=2, vertabla=False, precision=4):
    '''
    Método de Newton-Raphson para encontrar raíces.
    fx y dfx son funciones en forma de lambda (numéricas).
    xi es el punto inicial de búsqueda.
    tolera es la tolerancia permitida.
    iteramax es el máximo número de iteraciones permitidas.
    vertabla habilita o deshabilita la impresión de la tabla de iteraciones.
    '''
    itera = 0
    tramo = abs(2 * tolera)  # Inicialmente, aseguramos que el bucle comience
    if vertabla:
        print('Método de Newton-Raphson')
        print('i', ['xi', 'fi', 'dfi', 'xnuevo', 'tramo'])
        np.set_printoptions(precision)
    
    while tramo >= tolera and itera < iteramax:
        fi = fx(xi)
        dfi = dfx(xi)
        xnuevo = xi - fi / dfi  # Fórmula de Newton-Raphson
        tramo = abs(xnuevo - xi)  # Error absoluto
        if vertabla:
            print(itera, np.array([xi, fi, dfi, xnuevo, tramo]))
        xi = xnuevo
        itera += 1

    if itera >= iteramax:
        xi = np.nan  # No converge
        print('Iteraciones: ', itera, 'No converge, se alcanzó el máximo de iteraciones')

    return xi

# INGRESO
fx = lambda x: -x**3 - np.cos(x)  # Usamos np.cos para la función coseno
dfx = lambda x: -3 * (x**2) + np.sin(x)  # Usamos np.sin para la función seno

x0 = -1  # Aproximación inicial
tolera = 0.001  # Tolerancia

# PROCEDIMIENTO
respuesta = newton_raphson(fx, dfx, x0, tolera, vertabla=True)

# SALIDA
print('Raíz en: ', respuesta)
# Out:
# Método de Newton-Raphson
# i ['xi', 'fi', 'dfi', 'xnuevo', 'tramo']
# 0 [-1.      0.4597 -3.8415 -0.8803  0.1197]
# 1 [-0.8803  0.0454 -3.0959 -0.8657  0.0146]
# Iteraciones:  2 No converge, se alcanzó el máximo de iteraciones
# Raíz en:  nan

# %% [markdown]
# ### Con el metodo de la Secante:

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: x**3 + 4*x**2 - 10
a = 1
b = 5
tolera = 0.001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [  3.        5.        2.34568  53.      215.     ] 2.654320987654321
# 1 [  5.        2.34568   1.99777 215.       24.91526] 0.3479137443374638
# 2 [ 2.34568  1.99777  1.55605 24.91526 13.93748] 0.44171402596359677
# 3 [ 1.99777  1.55605  1.41058 13.93748  3.45284] 0.1454670092681074
# 4 [1.55605 1.41058 1.36913 3.45284 0.7657 ] 0.04145066408588649
# 5 [1.41058 1.36913 1.36532 0.7657  0.06458] 0.00381830238419667
# 6 [1.36913 1.36532 1.36523 0.06458 0.00141] 8.5089980760511e-05
# raíz en:  1.3652301763256676

# %% [markdown]
# ## EJERCICIO 2.- Encuentre soluciones precisas dentro de 10^−4 para los siguientes problemas.
# ## a. 𝑥^3 − 2𝑥^2 − 5 = 0, [1,4 ]

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: x**3 - 2*x**2 - 5
a = 1
b = 4
tolera = 0.0001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [ 2.5     4.      2.5974 -1.875  27.    ] 1.4025974025974026
# 1 [ 4.       2.5974   2.64603 27.      -0.96962] 0.04862385905589095
# 2 [ 2.5974   2.64603  2.69308 -0.96962 -0.47687] 0.04705734815552853
# 3 [ 2.64603  2.69308  2.69059 -0.47687  0.02673] 0.0024976083723760034
# 4 [ 2.69308e+00  2.69059e+00  2.69065e+00  2.67292e-02 -6.71062e-04] 6.11691589860186e-05
# raíz en:  2.690647365400627

# %% [markdown]
# ## b) 𝑥^3 + 3𝑥^2 − 1 = 0, [−3, −2]

# %%
 # Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: x**3 + 3*x**2 - 1
a = -3
b = -2
tolera = 0.0001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [-2.5     -2.      -3.71429  2.125    3.     ] 1.7142857142857144
# 1 [ -2.       -3.71429  -2.37121   3.      -10.85423] 1.3430735930735933
# 2 [ -3.71429  -2.37121  -2.62553 -10.85423   2.53545] 0.25432265983707714
# 3 [-2.37121 -2.62553 -3.04706  2.53545  1.58135] 0.42152056922500325
# 4 [-2.62553 -3.04706 -2.84638  1.58135 -1.43689] 0.2006725722121363
# 5 [-3.04706 -2.84638 -2.87557 -1.43689  0.24459] 0.02919016359365134
# 6 [-2.84638 -2.87557 -2.87948  0.24459  0.02888] 0.003907664073194539
# 7 [-2.87557e+00 -2.87948e+00 -2.87938e+00  2.88774e-02 -7.24463e-04] 9.563456642691648e-05
# raíz en:  -2.879384971162484

# %% [markdown]
# ## c) 𝑥 − cos 𝑥 = 0, [0,𝜋/2]

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: x - np.cos(x)
a = 0
b = np.pi/ 2
tolera = 0.0001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [0.7854  1.5708  0.7442  0.07829 1.5708 ] 0.8265972951131748
# 1 [1.5708  0.7442  0.73967 1.5708  0.00857] 0.0045336272467231264
# 2 [0.7442  0.73967 0.73909 0.00857 0.00097] 0.0005796179464514495
# 3 [7.39665e-01 7.39086e-01 7.39085e-01 9.71273e-04 1.09333e-06] 6.531897100980899e-07
# raíz en:  0.7390851332988371

# %% [markdown]
# ## d) 𝑥 − 0.8 − 0.2 sen 𝑥 = 0, [0,𝜋/2]

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: x - 0.8 - (0.2)*(np.sin(x))
a = 0
b = np.pi/ 2
tolera = 0.0001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [ 0.7854   1.5708   0.954   -0.15602  0.5708 ] 0.6168001472552677
# 1 [ 1.5708   0.954    0.96373  0.5708  -0.00915] 0.009732002279658536
# 2 [ 9.53996e-01  9.63728e-01  9.64334e-01 -9.15052e-03 -5.36630e-04] 0.0006062856802727667
# 3 [ 9.63728e-01  9.64334e-01  9.64334e-01 -5.36630e-04  5.13711e-07] 5.798369037135487e-07
# raíz en:  0.9643338876626565

# %% [markdown]
# ## EJERCICIO 3  Use los 2 métodos en esta sección para encontrar las soluciones dentro de 10^−5 para los siguientes problemas.

# %% [markdown]
# ## a) 3𝑥 − ℯ^𝑥 = 0 para 1 ≤ 𝑥 ≤ 2

# %%
import numpy as np
import matplotlib.pyplot as plt

def newton_raphson(fx, dfx, xi, tolera, iteramax=100, vertabla=False, precision=4):
    '''
    Método de Newton-Raphson para encontrar raíces.
    fx y dfx son funciones en forma de lambda (numéricas).
    xi es el punto inicial de búsqueda.
    tolera es la tolerancia permitida.
    iteramax es el máximo número de iteraciones permitidas.
    vertabla habilita o deshabilita la impresión de la tabla de iteraciones.
    '''
    itera = 0
    tramo = abs(2 * tolera)  # Inicialmente, aseguramos que el bucle comience
    if vertabla:
        print('Método de Newton-Raphson')
        print('i', ['xi', 'fi', 'dfi', 'xnuevo', 'tramo'])
        np.set_printoptions(precision)
    
    while tramo >= tolera and itera < iteramax:
        fi = fx(xi)
        dfi = dfx(xi)
        xnuevo = xi - fi / dfi  # Fórmula de Newton-Raphson
        tramo = abs(xnuevo - xi)  # Error absoluto
        if vertabla:
            print(itera, np.array([xi, fi, dfi, xnuevo, tramo]))
        xi = xnuevo
        itera += 1

    if itera >= iteramax:
        xi = np.nan  # No converge
        print('Iteraciones: ', itera, 'No converge, se alcanzó el máximo de iteraciones')

    return xi

# INGRESO
fx = lambda x: 3*x - np.e**x  # Usamos np.cos para la función coseno
dfx = lambda x: 3  - np.e**x  # Usamos np.sin para la función seno

x0 = 1.5  # Aproximación inicial
tolera = 0.00001  # Tolerancia

# PROCEDIMIENTO
respuesta = newton_raphson(fx, dfx, x0, tolera, vertabla=True)

# SALIDA
print('Raíz en: ', respuesta)
# Out:
# Método de Newton-Raphson
# i ['xi', 'fi', 'dfi', 'xnuevo', 'tramo']
# 0 [ 1.5     0.0183 -1.4817  1.5124  0.0124]
# 1 [ 1.5124e+00 -3.4364e-04 -1.5374e+00  1.5121e+00  2.2352e-04]
# 2 [ 1.5121e+00 -1.1334e-07 -1.5364e+00  1.5121e+00  7.3769e-08]
# Raíz en:  1.5121345516578504

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: 3*x - np.e**x 
a = 1
b = 2
tolera = 0.0001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [ 1.5      2.       1.50651  0.01831 -1.38906] 0.4934946146634376
# 1 [ 2.       1.50651  1.50953 -1.38906  0.00858] 0.003028455972243549
# 2 [1.50651 1.50953 1.51216 0.00858 0.00398] 0.002622528541452507
# 3 [ 1.50953e+00  1.51216e+00  1.51213e+00  3.98041e-03 -3.35226e-05] 2.1902209778046355e-05
# raíz en:  1.5121344676404804

# %% [markdown]
# ## b) 2𝑥 + 3 cos 𝑥 − ℯ^𝑥 = 0 para 1 ≤ 𝑥 ≤ 2

# %%
import numpy as np
import matplotlib.pyplot as plt

def newton_raphson(fx, dfx, xi, tolera, iteramax=100, vertabla=False, precision=4):
    '''
    Método de Newton-Raphson para encontrar raíces.
    fx y dfx son funciones en forma de lambda (numéricas).
    xi es el punto inicial de búsqueda.
    tolera es la tolerancia permitida.
    iteramax es el máximo número de iteraciones permitidas.
    vertabla habilita o deshabilita la impresión de la tabla de iteraciones.
    '''
    itera = 0
    tramo = abs(2 * tolera)  # Inicialmente, aseguramos que el bucle comience
    if vertabla:
        print('Método de Newton-Raphson')
        print('i', ['xi', 'fi', 'dfi', 'xnuevo', 'tramo'])
        np.set_printoptions(precision)
    
    while tramo >= tolera and itera < iteramax:
        fi = fx(xi)
        dfi = dfx(xi)
        xnuevo = xi - fi / dfi  # Fórmula de Newton-Raphson
        tramo = abs(xnuevo - xi)  # Error absoluto
        if vertabla:
            print(itera, np.array([xi, fi, dfi, xnuevo, tramo]))
        xi = xnuevo
        itera += 1

    if itera >= iteramax:
        xi = np.nan  # No converge
        print('Iteraciones: ', itera, 'No converge, se alcanzó el máximo de iteraciones')

    return xi

# INGRESO
fx = lambda x: 2*x + 3*np.cos(x)- np.e**x  # Usamos np.cos para la función coseno
dfx = lambda x: -3*np.sin(x) - np.e**x + 2  # Usamos np.sin para la función seno

x0 = 1.5  # Aproximación inicial
tolera = 0.00001  # Tolerancia

# PROCEDIMIENTO
respuesta = newton_raphson(fx, dfx, x0, tolera, vertabla=True)

# SALIDA
print('Raíz en: ', respuesta)
# Out:
# Método de Newton-Raphson
# i ['xi', 'fi', 'dfi', 'xnuevo', 'tramo']
# 0 [ 1.5    -1.2695 -5.4742  1.2681  0.2319]
# 1 [ 1.2681 -0.1236 -4.4177  1.2401  0.028 ]
# 2 [ 1.2401e+00 -1.7385e-03 -4.2935e+00  1.2397e+00  4.0491e-04]
# 3 [ 1.2397e+00 -3.6315e-07 -4.2917e+00  1.2397e+00  8.4618e-08]
# Raíz en:  1.2397146979752212

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: 2*x + 3*np.cos(x)- np.e**x 
a = 1
b = 2
tolera = 0.00001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [ 1.5      2.       1.31154 -1.26948 -4.6375 ] 0.6884605477798467
# 1 [ 2.       1.31154  1.26056 -4.6375  -0.31972] 0.05097829577792412
# 2 [ 1.31154  1.26056  1.24046 -0.31972 -0.09043] 0.020105689497537327
# 3 [ 1.26056  1.24046  1.23972 -0.09043 -0.00318] 0.000732879089046401
# 4 [ 1.24046e+00  1.23972e+00  1.23971e+00 -3.18037e-03 -3.38612e-05] 7.886865147632705e-06
# raíz en:  1.2397147009904979

# %% [markdown]
# ## EJERCICIO 4: El polinomio de cuarto grado 𝑓(𝑥) = 230𝑥^4 + 18𝑥^3 + 9𝑥^2 − 221𝑥 − 9
# ## tiene dos ceros reales, uno en [−1,0] y el otro en [0,1]. Intente aproximar estos ceros dentro de 10^−6 con
# ## a)El método de la secante (use los extremos como las estimaciones iniciales)

# %% [markdown]
# ## Para [-1,0]

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: 230*x**4 + 18*x**3 + 9*x**2 -221*x -9
a = -1
b = 0
tolera = 0.000001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [-5.00000e-01  0.00000e+00 -3.60360e-02  1.15875e+02 -9.00000e+00] 0.036036036036036036
# 1 [ 0.      -0.03604 -0.04067 -9.      -1.0248 ] 0.004630587021376274
# 2 [-0.03604 -0.04067 -0.04066 -1.0248   0.00163] 7.336118658843316e-06
# 3 [-4.06666e-02 -4.06593e-02 -4.06593e-02  1.62615e-03 -3.05288e-07] 1.3770049822614538e-09
# raíz en:  -0.04065928831575845

# %% [markdown]
# ## Para [0,1]

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: 230*x**4 + 18*x**3 + 9*x**2 -221*x -9
a = 0
b = 1
tolera = 0.000001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [   0.5        1.         0.89422 -100.625     27.     ] 0.10577864838393736
# 1 [  1.        0.89422   0.95705  27.      -39.49083] 0.06282500205273012
# 2 [  0.89422   0.95705   0.96321 -39.49083  -3.52846] 0.006164091380568504
# 3 [ 0.95705  0.96321  0.96239 -3.52846  0.54203] 0.0008208126831183993
# 4 [ 0.96321  0.96239  0.9624   0.54203 -0.00586] 8.772062474182718e-06
# 5 [ 9.62390e-01  9.62398e-01  9.62398e-01 -5.85524e-03 -9.54423e-06] 1.4322077301898162e-08
# raíz en:  0.9623984187507943

# %% [markdown]
# ## b) El método de Newton (use el punto medio como estimación inicial)

# %% [markdown]
# ## Para [-1,0]

# %%
import numpy as np
import matplotlib.pyplot as plt

def newton_raphson(fx, dfx, xi, tolera, iteramax=100, vertabla=False, precision=4):
    '''
    Método de Newton-Raphson para encontrar raíces.
    fx y dfx son funciones en forma de lambda (numéricas).
    xi es el punto inicial de búsqueda.
    tolera es la tolerancia permitida.
    iteramax es el máximo número de iteraciones permitidas.
    vertabla habilita o deshabilita la impresión de la tabla de iteraciones.
    '''
    itera = 0
    tramo = abs(2 * tolera)  # Inicialmente, aseguramos que el bucle comience
    if vertabla:
        print('Método de Newton-Raphson')
        print('i', ['xi', 'fi', 'dfi', 'xnuevo', 'tramo'])
        np.set_printoptions(precision)
    
    while tramo >= tolera and itera < iteramax:
        fi = fx(xi)
        dfi = dfx(xi)
        xnuevo = xi - fi / dfi  # Fórmula de Newton-Raphson
        tramo = abs(xnuevo - xi)  # Error absoluto
        if vertabla:
            print(itera, np.array([xi, fi, dfi, xnuevo, tramo]))
        xi = xnuevo
        itera += 1

    if itera >= iteramax:
        xi = np.nan  # No converge
        print('Iteraciones: ', itera, 'No converge, se alcanzó el máximo de iteraciones')

    return xi

# INGRESO
fx = lambda x: 230*x**4 + 18*x**3 + 9*x**2 -221*x -9  # Usamos np.cos para la función coseno
dfx = lambda x: 920*x**3 + 54*x**2 + 18*x - 221  # Usamos np.sin para la función seno

x0 = -0.5  # Aproximación inicial
tolera = 0.000001  # Tolerancia

# PROCEDIMIENTO
respuesta = newton_raphson(fx, dfx, x0, tolera, vertabla=True)

# SALIDA
print('Raíz en: ', respuesta)
# Out:
# Método de Newton-Raphson
# i ['xi', 'fi', 'dfi', 'xnuevo', 'tramo']
# 0 [-5.0000e-01  1.1588e+02 -3.3150e+02 -1.5045e-01  3.4955e-01]
# 1 [-1.5045e-01  2.4510e+01 -2.2562e+02 -4.1817e-02  1.0864e-01]
# 2 [-4.1817e-02  2.5664e-01 -2.2173e+02 -4.0659e-02  1.1575e-03]
# 3 [-4.0659e-02  1.2234e-05 -2.2170e+02 -4.0659e-02  5.5182e-08]
# Raíz en:  -0.04065928831575899

# %% [markdown]
# ## Para [0,1]

# %%
import numpy as np
import matplotlib.pyplot as plt

def newton_raphson(fx, dfx, xi, tolera, iteramax=100, vertabla=False, precision=4):
    '''
    Método de Newton-Raphson para encontrar raíces.
    fx y dfx son funciones en forma de lambda (numéricas).
    xi es el punto inicial de búsqueda.
    tolera es la tolerancia permitida.
    iteramax es el máximo número de iteraciones permitidas.
    vertabla habilita o deshabilita la impresión de la tabla de iteraciones.
    '''
    itera = 0
    tramo = abs(2 * tolera)  # Inicialmente, aseguramos que el bucle comience
    if vertabla:
        print('Método de Newton-Raphson')
        print('i', ['xi', 'fi', 'dfi', 'xnuevo', 'tramo'])
        np.set_printoptions(precision)
    
    while tramo >= tolera and itera < iteramax:
        fi = fx(xi)
        dfi = dfx(xi)
        xnuevo = xi - fi / dfi  # Fórmula de Newton-Raphson
        tramo = abs(xnuevo - xi)  # Error absoluto
        if vertabla:
            print(itera, np.array([xi, fi, dfi, xnuevo, tramo]))
        xi = xnuevo
        itera += 1

    if itera >= iteramax:
        xi = np.nan  # No converge
        print('Iteraciones: ', itera, 'No converge, se alcanzó el máximo de iteraciones')

    return xi

# INGRESO
fx = lambda x: 230*x**4 + 18*x**3 + 9*x**2 -221*x -9  # Usamos np.cos para la función coseno
dfx = lambda x: 920*x**3 + 54*x**2 + 18*x - 221  # Usamos np.sin para la función seno

x0 = 0.5  # Aproximación inicial
tolera = 0.000001  # Tolerancia

# PROCEDIMIENTO
respuesta = newton_raphson(fx, dfx, x0, tolera, vertabla=True)

# SALIDA
print('Raíz en: ', respuesta)
# Out:
# Método de Newton-Raphson
# i ['xi', 'fi', 'dfi', 'xnuevo', 'tramo']
# 0 [   0.5    -100.625   -83.5      -0.7051    1.2051]
# 1 [-7.0509e-01  2.0184e+02 -5.2934e+02 -3.2379e-01  3.8130e-01]
# 2 [-3.2379e-01  6.5418e+01 -2.5240e+02 -6.4603e-02  2.5919e-01]
# 3 [-6.4603e-02  5.3140e+00 -2.2219e+02 -4.0686e-02  2.3917e-02]
# 4 [-4.0686e-02  5.9556e-03 -2.2170e+02 -4.0659e-02  2.6863e-05]
# 5 [-4.0659e-02  6.5571e-09 -2.2170e+02 -4.0659e-02  2.9576e-11]
# Raíz en:  -0.040659288315758865

# %% [markdown]
# ## EJERCICIO 5: La función 𝑓(𝑥) = tan 𝜋 𝑥 − 6 tiene cero en (1/𝜋) arcotangente 6 ≈ 0.447431543. Sea 𝑝0 = 0 y 𝑝1 = 0.48 y use 10 iteraciones en cada uno de los siguientes métodos para aproximar esta raíz. ¿Cuál método es más eficaz y por qué?
# ## a) método de bisección

# %%
# Algoritmo de Bisección
# [a,b] se escogen de la gráfica de la función
# error = tolera
import numpy as np

def biseccion(fx,a,b,tolera,iteramax = 20, vertabla=False, precision=4):
    '''
    Algoritmo de Bisección
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    error = tolera
    '''
    fa = fx(a)
    fb = fx(b)
    tramo = np.abs(b-a)
    itera = 0
    cambia = np.sign(fa)*np.sign(fb)
    if cambia<0: # existe cambio de signo f(a) vs f(b)
        if vertabla==True:
            print('método de Bisección')
            print('i', ['a','c','b'],[ 'f(a)', 'f(c)','f(b)'])
            print('  ','tramo')
            np.set_printoptions(precision)
            
        while (tramo>=tolera and itera<=iteramax):
            c = (a+b)/2
            fc = fx(c)
            cambia = np.sign(fa)*np.sign(fc)
            if vertabla==True:
                print(itera,[a,c,b],np.array([fa,fc,fb]))
            if (cambia<0):
                b = c
                fb = fc
            else:
                a = c
                fa = fc
            tramo = np.abs(b-a)
            if vertabla==True:
                print('  ',tramo)
            itera = itera + 1
        respuesta = c
        # Valida respuesta
        if (itera>=iteramax):
            respuesta = np.nan

    else: 
        print(' No existe cambio de signo entre f(a) y f(b)')
        print(' f(a) =',fa,',  f(b) =',fb) 
        respuesta=np.nan
    return(respuesta)

# INGRESO
fx  = lambda x: np.tan(np.pi*x)-6
a = 0
b = 0.48
tolera = 0.001

# PROCEDIMIENTO
respuesta = biseccion(fx,a,b,tolera,vertabla=True)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de Bisección
# i ['a', 'c', 'b'] ['f(a)', 'f(c)', 'f(b)']
#    tramo
# 0 [0, 0.24, 0.48] [-6.     -5.0609  9.8945]
#    0.24
# 1 [0.24, 0.36, 0.48] [-5.0609 -3.8749  9.8945]
#    0.12
# 2 [0.36, 0.42, 0.48] [-3.8749 -2.1053  9.8945]
#    0.06
# 3 [0.42, 0.44999999999999996, 0.48] [-2.1053  0.3138  9.8945]
#    0.02999999999999997
# 4 [0.42, 0.43499999999999994, 0.44999999999999996] [-2.1053 -1.1712  0.3138]
#    0.015000000000000013
# 5 [0.43499999999999994, 0.44249999999999995, 0.44999999999999996] [-1.1712 -0.5245  0.3138]
#    0.007500000000000007
# 6 [0.44249999999999995, 0.4462499999999999, 0.44999999999999996] [-0.5245 -0.1343  0.3138]
#    0.003750000000000031
# 7 [0.4462499999999999, 0.44812499999999994, 0.44999999999999996] [-0.1343  0.0817  0.3138]
#    0.0018750000000000155
# 8 [0.4462499999999999, 0.44718749999999996, 0.44812499999999994] [-0.1343 -0.0282  0.0817]
#    0.00093749999999998
# raíz en:  0.44718749999999996

# %% [markdown]
# ## b) Método de Newton

# %%
import numpy as np
import matplotlib.pyplot as plt

def newton_raphson(fx, dfx, xi, tolera, iteramax=100, vertabla=False, precision=4):
    '''
    Método de Newton-Raphson para encontrar raíces.
    fx y dfx son funciones en forma de lambda (numéricas).
    xi es el punto inicial de búsqueda.
    tolera es la tolerancia permitida.
    iteramax es el máximo número de iteraciones permitidas.
    vertabla habilita o deshabilita la impresión de la tabla de iteraciones.
    '''
    itera = 0
    tramo = abs(2 * tolera)  # Inicialmente, aseguramos que el bucle comience
    if vertabla:
        print('Método de Newton-Raphson')
        print('i', ['xi', 'fi', 'dfi', 'xnuevo', 'tramo'])
        np.set_printoptions(precision)
    
    while tramo >= tolera and itera < iteramax:
        fi = fx(xi)
        dfi = dfx(xi)
        xnuevo = xi - fi / dfi  # Fórmula de Newton-Raphson
        tramo = abs(xnuevo - xi)  # Error absoluto
        if vertabla:
            print(itera, np.array([xi, fi, dfi, xnuevo, tramo]))
        xi = xnuevo
        itera += 1

    if itera >= iteramax:
        xi = np.nan  # No converge
        print('Iteraciones: ', itera, 'No converge, se alcanzó el máximo de iteraciones')

    return xi

# INGRESO
fx = lambda x: np.tan(np.pi*x)-6 
dfx = lambda x: np.pi/(np.cos(np.pi*x))**2

x0 = 0.24 # Aproximación inicial
tolera = 0.001  # Tolerancia

# PROCEDIMIENTO
respuesta = newton_raphson(fx, dfx, x0, tolera, vertabla=True)

# SALIDA
print('Raíz en: ', respuesta)
# Out:
# Método de Newton-Raphson
# i ['xi', 'fi', 'dfi', 'xnuevo', 'tramo']
# 0 [ 0.24   -5.0609  5.912   1.096   0.856 ]
# 1 [ 1.096  -5.6887  3.4459  2.7469  1.6509]
# 2 [ 2.7469 -7.0197  6.4079  3.8424  1.0955]
# 3 [ 3.8424 -6.5401  4.058   5.454   1.6117]
# 4 [5.4540e+00 8.7757e-01 1.5174e+02 5.4483e+00 5.7833e-03]
# 5 [5.4483e+00 9.7401e-02 1.1994e+02 5.4474e+00 8.1207e-04]
# Raíz en:  5.447444373471457

# %% [markdown]
# ## c) Método de la secante

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=20,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: np.tan(np.pi*x)-6 
a = 0
b = 0.48
tolera = 0.0001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [ 0.24     0.48     0.32122 -5.06094  9.89454] 0.15878396355604574
# 1 [ 0.48     0.32122  0.37017  9.89454 -4.41087] 0.04895872879828822
# 2 [ 0.32122  0.37017  0.61899 -4.41087 -3.68565] 0.24881573226275455
# 3 [ 0.37017  0.61899  0.18162 -3.68565 -8.5493 ] 0.43736701646913273
# 4 [ 0.61899  0.18162 -0.55276 -8.5493  -5.3582 ] 0.7343865264335192
# 5 [ 0.18162 -0.55276 -0.55586 -5.3582  -0.02254] 0.003101810005523342
# 6 [-0.55276 -0.55586 -0.55256 -0.02254 -0.36077] 0.003308482194284812
# 7 [-0.55586 -0.55256 -0.55257 -0.36077  0.0014 ] 1.2833888362928647e-05
# raíz en:  -0.5525692070972563

# %% [markdown]
# ## Resp. El más eficaz resultó ser el método de la bisección, porque fue el único que se acercó a la respuesta.

# %% [markdown]
# ## EJERCICIO 6:La función descrita por 𝑓(𝑥) = ln(𝑥^2 + 1) − ℯ^0.4𝑥*cos𝜋𝑥 tiene un número infinito de ceros.
# ## a. Determine, dentro de 10^−6, el único cero negativo.
# ## b. Determine, dentro de 10^−6, los cuatro ceros positivos más pequeños.
# ## c. Determine una aproximación inicial razonable para encontrar el enésimo cero positivo más pequeño de 𝑓.
# ## [Sugerencia: Dibuje una gráfica aproximada de 𝑓.]
# ## d. Use la parte c) para determinar, dentro de 10^−6, el vigesimoquinto cero positivo más pequeño de 𝑓.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import newton

# Definición de la función y su derivada
f = lambda x: np.log(x**2 + 1) - np.exp(0.4 * x) * np.cos(np.pi * x)
df = lambda x: (2 * x / (x**2 + 1)) - np.exp(0.4 * x) * (0.4 * np.cos(np.pi * x) - np.pi * np.sin(np.pi * x))

# Gráfica para identificar ceros
x_vals = np.linspace(-5, 30, 1000)
y_vals = f(x_vals)
plt.plot(x_vals, y_vals, label="f(x)")
plt.axhline(0, color='red', linestyle='--')
plt.title("Gráfica de f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.legend()
plt.show()

# a) Encontrar el único cero negativo
cero_negativo = newton(f, x0=-1, fprime=df, tol=1e-6)
print("Único cero negativo:", cero_negativo)

# b) Encontrar los cuatro ceros positivos más pequeños
ceros_positivos = []
aproximaciones_iniciales = [0.5, 2.5, 4.5, 6.5]  # Aproximaciones iniciales basadas en la gráfica
for x0 in aproximaciones_iniciales:
    raiz = newton(f, x0=x0, fprime=df, tol=1e-6)
    ceros_positivos.append(raiz)

print("Cuatro ceros positivos más pequeños:", ceros_positivos)

# c) Aproximación inicial para el enésimo cero positivo
print("Aproximación inicial para enésimo cero positivo: Use la gráfica para identificar el patrón.")

# d) Encontrar el vigesimoquinto cero positivo
aproximacion_25 = 2 * 25 - 0.5  # Patrones observados en la gráfica
cero_25 = newton(f, x0=aproximacion_25, fprime=df, tol=1e-6)
print("Vigesimoquinto cero positivo:", cero_25)
# Out:
# Único cero negativo: 0.4506567478899403
# Cuatro ceros positivos más pequeños: [0.45065674789059323, 2.2383197950741383, 4.322648959394466, 6.406933614179465]
# Aproximación inicial para enésimo cero positivo: Use la gráfica para identificar el patrón.
# Vigesimoquinto cero positivo: 49.50000000625398

# %% [markdown]
# ## EJERCICIO 7: La función 𝑓(𝑥) = 𝑥^(1/3) tiene raíz en 𝑥 = 0.Usando el punto de inicio de 𝑥 = 1 y 𝑝0 = 5, 𝑝1 = 0.5 para el método de secante, compare los resultados de los métodos de la secante y de Newton.

# %% [markdown]
# ## Con el método de la secante:

# %%
# Método de secante
import numpy as np

def secante_raiz(fx,a,b,tolera, iteramax=10,
                 vertabla=True, precision=6):
    '''fx en forma numérica lambda
    Los valores de [a,b] son seleccionados
    desde la gráfica de la función
    '''
    xi_1 = a
    xi = b
    itera = 0
    tramo = np.abs(xi-xi_1)
    if vertabla==True:
        print('método de la Secante')
        print('i','[ x[i-1], xi, x[i+1], f[i-1], fi ]','tramo')
        np.set_printoptions(precision)
    while not(tramo<tolera or itera>iteramax):
        fi_1 = fx(xi_1)
        fi = fx(xi)
        xi1 = xi-fi*(xi_1 - xi)/(fi_1-fi)
        tramo = np.abs(xi1-xi)
        if vertabla==True:
            print(itera,np.array([xi_1,xi,xi1,fi_1,fi]),tramo)
        xi_1 = xi
        xi = xi1
        itera = itera + 1
    if itera>=iteramax:
        xi = np.nan
        print('itera: ',itera,
              'No converge,se alcanzó el máximo de iteraciones')
    respuesta = xi
    
    return(respuesta)

# INGRESO
fx = lambda x: x**(1/3)
a = 0.5
b = 5
tolera = 0.001
c = (a+b)/2 # probar dos puntos en un mismo lado de f(x)

# PROCEDIMIENTO
respuesta = secante_raiz(fx,c,b,tolera,
                         vertabla=True,precision = 5)
# SALIDA
print('raíz en: ', respuesta)
# Out:
# método de la Secante
# i [ x[i-1], xi, x[i+1], f[i-1], fi ] tramo
# 0 [ 2.75     5.      -7.45304  1.40102  1.70998] 12.45304307529652
# 1 [ 5.      +0.j      -7.45304 +0.j       0.40644-10.59676j
#   1.70998 +0.j       0.97667 +1.69164j] 13.193281212356078
# 2 [-7.45304 +0.j       0.40644-10.59676j -9.31823 -8.623j
#   0.97667 +1.69164j  1.91654 -1.0741j ] 9.922947231385931
# 3 [ 0.40644-10.59676j -9.31823 -8.623j    8.8894 +21.18842j
#   1.91654 -1.0741j   1.62814 -1.67074j] 34.93191480969855
# 4 [ -9.31823 -8.623j     8.8894 +21.18842j -24.38048+14.7511j
#    1.62814 -1.67074j   2.62818 +1.08397j] 33.886924746679306
# 5 [  8.8894 +21.18842j -24.38048+14.7511j   15.8182 -47.19583j
#    2.62818 +1.08397j   1.97929 +2.32633j] 73.8468494525915
# 6 [-24.38048+14.7511j   15.8182 -47.19583j -49.96141-34.62332j
#    1.97929 +2.32633j   3.36509 -1.48584j] 66.97033111357439
# 7 [ 15.8182  -47.19583j -49.96141 -34.62332j  34.64223+101.81711j
# ...

# %% [markdown]
# ## Por el método de Newton

# %%
import numpy as np
import matplotlib.pyplot as plt

def newton_raphson(fx, dfx, xi, tolera, iteramax=10, vertabla=False, precision=4):
    '''
    Método de Newton-Raphson para encontrar raíces.
    fx y dfx son funciones en forma de lambda (numéricas).
    xi es el punto inicial de búsqueda.
    tolera es la tolerancia permitida.
    iteramax es el máximo número de iteraciones permitidas.
    vertabla habilita o deshabilita la impresión de la tabla de iteraciones.
    '''
    itera = 0
    tramo = abs(2 * tolera)  # Inicialmente, aseguramos que el bucle comience
    if vertabla:
        print('Método de Newton-Raphson')
        print('i', ['xi', 'fi', 'dfi', 'xnuevo', 'tramo'])
        np.set_printoptions(precision)
    
    while tramo >= tolera and itera < iteramax:
        fi = fx(xi)
        dfi = dfx(xi)
        xnuevo = xi - fi / dfi  # Fórmula de Newton-Raphson
        tramo = abs(xnuevo - xi)  # Error absoluto
        if vertabla:
            print(itera, np.array([xi, fi, dfi, xnuevo, tramo]))
        xi = xnuevo
        itera += 1

    if itera >= iteramax:
        xi = np.nan  # No converge
        print('Iteraciones: ', itera, 'No converge, se alcanzó el máximo de iteraciones')

    return xi

# INGRESO
fx = lambda x: x**(1/3)
dfx = lambda x: (1/3) * (x**(-2/3))

x0 = 1 # Aproximación inicial
tolera = 0.001  # Tolerancia

# PROCEDIMIENTO
respuesta = newton_raphson(fx, dfx, x0, tolera, vertabla=True)

# SALIDA
print('Raíz en: ', respuesta)
# Out:
# Método de Newton-Raphson
# i ['xi', 'fi', 'dfi', 'xnuevo', 'tramo']
# 0 [ 1.      1.      0.3333 -2.      3.    ]
# 1 [-2.   +0.0000e+00j  0.63 +1.0911e+00j -0.105-1.8185e-01j
#   4.   -2.2894e-15j  6.   +0.0000e+00j]
# 2 [ 4.    -2.2894e-15j  1.5874-3.0285e-16j  0.1323+5.0475e-17j
#  -8.    +4.5788e-15j 12.    +0.0000e+00j]
# 3 [-8.    +4.5788e-15j  1.    +1.7321e+00j -0.0417-7.2169e-02j
#  16.    -1.9651e-14j 24.    +0.0000e+00j]
# 4 [ 16.    -1.9651e-14j   2.5198-1.0316e-15j   0.0525+4.2983e-17j
#  -32.    +3.9301e-14j  48.    +0.0000e+00j]
# 5 [-3.2000e+01+3.9301e-14j  1.5874e+00+2.7495e+00j -1.6535e-02-2.8640e-02j
#   6.4000e+01-5.9548e-14j  9.6000e+01+0.0000e+00j]
# 6 [ 6.4000e+01-5.9548e-14j  4.0000e+00-1.2406e-15j  2.0833e-02+1.2923e-17j
#  -1.2800e+02+1.1910e-13j  1.9200e+02+0.0000e+00j]
# 7 [-1.2800e+02+1.1910e-13j  2.5198e+00+4.3645e+00j -6.5621e-03-1.1366e-02j
#   2.5600e+02-2.6186e-13j  3.8400e+02+0.0000e+00j]
# ...

# %% [markdown]
# ## Resp. Ninguno converge a 0, pero en el de la secante se aproxima en la 3ra iteración con un 0,406
